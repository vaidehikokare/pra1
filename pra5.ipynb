# %%
from sklearn.ensemble import IsolationForest
# The Isolation Forest is an unsupervised machine learning algorithm used primarily for anomaly detection
# (also known as outlier detection). 
# It works particularly well with high-dimensional datasets and is efficient even with large datasets.

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import fetch_kddcup99
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data=fetch_kddcup99(subset="SA",percent10=True)

# %%
X=pd.DataFrame(data.data)
y=data.target

# %%
lb=LabelEncoder()
for i in X.columns:
    if X[i].dtype==object:
        X[i]=LabelEncoder().fit_transform(X[i])

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
model=IsolationForest(contamination=0.1,random_state=42)

# %%
model.fit(X)
# Out:
# IsolationForest(contamination=0.1, random_state=42)

# %%
y_pred=model.predict(X)

# %%
y_pred=np.where(y_pred==1,0,1)

# %%
Y=np.where(y==b'normal.',0,1)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y, y_pred)
print(f"Anomaly Detection Accuracy: {accuracy:.2f}")
# Out:
# Anomaly Detection Accuracy: 0.90
